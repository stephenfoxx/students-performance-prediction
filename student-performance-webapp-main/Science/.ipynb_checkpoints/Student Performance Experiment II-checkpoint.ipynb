# %% [markdown]
# # Student Performance Analysis and Prediction
#
# ## Introduction
# This project aims to analyze and predict student performance based on various factors, including demographic details, study habits, parental involvement, and participation in extracurricular activities. By understanding these influences, we can identify patterns and provide actionable insights to improve educational outcomes.
#
#
# ## Table of Contents
#
# * Student Information
# * Demographic Details
# * Study Habits
# * Parental Involvement
# * Extracurricular Activities
# * Academic Performance
# * Target Variable: Grade Class
#
# 1. ### Student Information
# * StudentID: A unique identifier assigned to each student (1001 to 3392).
#
# 2. ### Demographic Details
# * Age: The age of the students ranges from 15 to 18 years.
# * Gender: Gender of the students, where 0 represents Male and 1 represents Female.
# * Ethnicity: The ethnicity of the students, coded as follows:
# >0: Caucasian
# 1: African American
# 2: Asian
# 3: Other
# * ParentalEducation: The education level of the parents, coded as follows:
# > 0: None
# 1: High School
# 2: Some College
# 3: Bachelor's
# 4: Higher
#
# 3. ### Study Habits
# * StudyTimeWeekly: Weekly study time in hours, ranging from 0 to 20.
# * Absences: Number of absences during the school year, ranging from 0 to 30.
# * Tutoring: Tutoring status, where 0 indicates No and 1 indicates Yes.
#
# 4. ### Parental Involvement
# * ParentalSupport: The level of parental support, coded as follows:
# > 0: None
# 1: Low
# 2: Moderate
# 3: High
# 4: Very High
#
# 5. ### Extracurricular Activities
# * Extracurricular: Participation in extracurricular activities, where 0 indicates No and 1 indicates Yes.
# * Sports: Participation in sports, where 0 indicates No and 1 indicates Yes.
# * Music: Participation in music activities, where 0 indicates No and 1 indicates Yes.
# * Volunteering: Participation in volunteering, where 0 indicates No and 1 indicates Yes.
#
# 6. ### Academic Performance
# * GPA: Grade Point Average on a scale from 2.0 to 4.0, influenced by study habits, parental involvement, and extracurricular activities.
# Target Variable: Grade Class
# * GradeClass: Classification of students' grades based on GPA:
# >0: 'A' (GPA >= 3.5)
# 1: 'B' (3.0 <= GPA < 3.5)
# 2: 'C' (2.5 <= GPA < 3.0)
# 3: 'D' (2.0 <= GPA < 2.5)
# 4: 'F' (GPA < 2.0)

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Libraries Importation
# We begin by importing essential libraries for data manipulation, visualization, and modeling. These include pandas, numpy, matplotlib, seaborn, and several Scikit-learn modules.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, f1_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import RepeatedStratifiedKFold, RandomizedSearchCV, GridSearchCV, train_test_split
from scipy.stats import loguniform
from xgboost import XGBClassifier

# Set plot style
sns.set(style='whitegrid')

# %% [markdown]
# ## Data Collection and Loading
# The dataset is loaded into a pandas DataFrame. This dataset contains various attributes related to students, such as demographic details, study habits, parental involvement, extracurricular activities, and academic performance.

# %%
# Load the dataset
file_path = 'Student_performance_data.csv'
data = pd.read_csv(file_path)

# %%
# Display the first few rows of the dataset
display(data.head())
display(data.tail())
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# 2387             0  3.455509         0.0
# 2388             0  3.279150         4.0
# 2389             1  1.142333         2.0
# 2390             0  1.803297         1.0
# 2391             1  2.140014         1.0

# %% [markdown]
# ## Data Cleaning
# Data cleaning involves handling missing values and ensuring that the data types of the features are appropriate. This step is crucial for ensuring the accuracy and reliability of our analysis and modeling.

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
# Convert categorical columns to appropriate data types
data['Gender'] = data['Gender'].astype('category')
data['Ethnicity'] = data['Ethnicity'].astype('category')
data['ParentalEducation'] = data['ParentalEducation'].astype('category')
data['Tutoring'] = data['Tutoring'].astype('category')
data['ParentalSupport'] = data['ParentalSupport'].astype('category')
data['Extracurricular'] = data['Extracurricular'].astype('category')
data['Sports'] = data['Sports'].astype('category')
data['Music'] = data['Music'].astype('category')
data['Volunteering'] = data['Volunteering'].astype('category')
data['GradeClass'] = data['GradeClass'].astype('category')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Exploratory Data Analysis helps us understand the distribution and relationships within the data. We use visualizations like correlation heatmaps and distribution plots to identify patterns and insights that will guide our modeling approach.

# %%
# Summary statistics
data.describe()
# Out:
#          StudentID          Age  StudyTimeWeekly     Absences          GPA
# count  2392.000000  2392.000000      2392.000000  2392.000000  2392.000000
# mean   2196.500000    16.468645         9.771992    14.541388     1.906186
# std     690.655244     1.123798         5.652774     8.467417     0.915156
# min    1001.000000    15.000000         0.001057     0.000000     0.000000
# 25%    1598.750000    15.000000         5.043079     7.000000     1.174803
# 50%    2196.500000    16.000000         9.705363    15.000000     1.893393
# 75%    2794.250000    17.000000        14.408410    22.000000     2.622216
# max    3392.000000    18.000000        19.978094    29.000000     4.000000

# %% [markdown]
# ### What is the distribution of GPA among students?

# %%
# Plot the distribution of GPA
plt.figure(figsize=(10, 6))
sns.histplot(data['GPA'], kde=True, bins=30, color='blue')
plt.title('Distribution of GPA')
plt.xlabel('GPA')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar chart for the 'GradeClass' column
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='GradeClass', data=data, palette='viridis')

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

for bar, color in zip(ax.patches, colors):
    bar.set_color(color)

# Custom Legend
legend_labels = ['Grade A', 'Grade B', 'Grade C', 'Grade D', 'Grade F']
custom_legend = [plt.Line2D([0], [0], color=color, lw=4) for color in colors]
plt.legend(custom_legend, legend_labels, title='Grade Classes')

# Adding titles and labels
plt.title('Grade Class Distribution of Students')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ### What is the average GPA and grade for each gender?

# %%
average_gpa_gender = data.groupby('Gender')['GPA'].mean()
average_gpa_gender
# Out:
# Gender
# 0    1.918679
# 1    1.894225
# Name: GPA, dtype: float64

# %%
# Plotting the average GPA by Parental Education Level

plt.figure(figsize=(12, 6))
average_gpa_gender.plot(kind='bar')
plt.title('Average GPA by Gender')
plt.xlabel('Gender')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Mapping of codes to labels
gender_labels = {
    0: 'Male',
    1: 'Female',
}
# Plot the relationship between GradeClass and Gender with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='Gender', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Gender')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in gender_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %% [markdown]
# ### How does parental education level and Parental Support affect student GPA?

# %%
average_gpa_parentaled = data.groupby('ParentalEducation')['GPA'].mean()
average_gpa_parentaled
# Out:
# ParentalEducation
# 0    1.893045
# 1    1.944022
# 2    1.929881
# 3    1.809082
# 4    1.815812
# Name: GPA, dtype: float64

# %%
# Plotting the average GPA by Parental Education Level

plt.figure(figsize=(12, 6))
average_gpa_parentaled.plot(kind='bar')
plt.title('Average GPA by Parental Education Level')
plt.xlabel('Parental Education Level')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Mapping of codes to labels
parental_support_labels = {
    0: 'None',
    1: 'Low',
    2: 'Moderate',
    3: 'High',
    4: 'Very High'
}

# Plot the relationship between GradeClass and ParentalSupport with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='ParentalSupport', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Parental Support')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in parental_support_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %% [markdown]
# ### Do students who participate in extracurricular activities have higher GPAs?

# %%
average_gpa_extracurricular = data.groupby('Extracurricular')['GPA'].mean()
average_gpa_extracurricular
# Out:
# Extracurricular
# 0    1.838316
# 1    2.015357
# Name: GPA, dtype: float64

# %%
plt.figure(figsize=(12, 6))
average_gpa_extracurricular.plot(kind='bar')
plt.title('Average GPA by Extracurricular Activity')
plt.xlabel('Extracurricular Activity')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Mapping of codes to labels
extracurricular_labels = {
    0: 'No',
    1: 'Yes',
}

# Plot the relationship between GradeClass and ParentalSupport with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='Extracurricular', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Extracurricular Activity')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in extracurricular_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %% [markdown]
# ### What is the distribution of study time and absences among students?

# %%
# Plot the distribution of study time
plt.figure(figsize=(10, 6))
sns.histplot(data['StudyTimeWeekly'], kde=True, bins=30, color='blue')
plt.title('Distribution of Study Time')
plt.xlabel('Study Time')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of A
plt.figure(figsize=(10, 6))
sns.histplot(data['Absences'], kde=True, bins=30, color='blue')
plt.title('Distribution of Absences')
plt.xlabel('Absences')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Is there a relationship between study time, Absences, Tutorinng and GPA?

# %%
# Plot Study Time vs GPA
plt.figure(figsize=(10, 6))
sns.regplot(data=data, x='StudyTimeWeekly', y='GPA', line_kws={'color': 'red'})
plt.title('Study Time vs GPA')
plt.xlabel('Study Time Weekly (hours)')
plt.ylabel('GPA')
plt.show()

# %%
correlation_study_time_gpa = data['StudyTimeWeekly'].corr(data['GPA'])
display(correlation_study_time_gpa)
# Out:
# np.float64(0.17927512685608818)

# %%
# Plot Absences vs GPA
plt.figure(figsize=(10, 6))
sns.regplot(x='Absences', y='GPA', data=data, line_kws={'color': 'red'})
plt.title('Absences vs GPA')
plt.xlabel('Number of Absences')
plt.ylabel('GPA')
plt.show()

# %%
correlation_absences_gpa = data['Absences'].corr(data['GPA'])
display(correlation_absences_gpa)
# Out:
# np.float64(-0.9193135764208643)

# %%
# Mapping of codes to labels
tutoring_labels = {
    0: 'No',
    1: 'Yes',
}

# Plot the relationship between GradeClass and Tutoring with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='Tutoring', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Tutoring')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in tutoring_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %%
# Plot correlation heatmap
plt.figure(figsize=(14, 8))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Analysis Summary
#
# The analysis of the student performance dataset reveals significant influences on GPA:
#
# - **Increased Study Time**: Students who spend more time studying each week tend to have higher GPAs.
# - **Participation in Extracurricular Activities**: Engagement in extracurricular activities such as sports, music, and volunteering is positively correlated with GPA.
# - **Attendance**: Higher numbers of absences are associated with lower GPAs.
#
# These insights underscore the importance of consistent attendance, and balanced extracurricular engagement in fostering academic success.

# %% [markdown]
# ## Train-Test Split
# To evaluate our model's performance, we split the data into training and testing sets. This allows us to train the model on one portion of the data and test it on another, ensuring that the model generalizes well to unseen data.

# %%
X = data.drop(columns=['GradeClass', 'GPA', 'StudentID', 'Age'])
y = data['GradeClass']

# Splitting the data into training and testing sets (e.g., 75% train, 25% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

# %% [markdown]
# ## Feature Selection
# In this step, we select the relevant features for our model. We drop unnecessary columns such as `StudentID`, `GPA`, `Age` and the target variable `GradeClass` from the feature set `X`, and define the target variable `y`.

# %%
# Train on the data to determine the feature importance using RandomForest Algorithm 
clf = RandomForestClassifier(random_state = 42)
clf = clf.fit(X, y)

fimp = pd.Series(data=clf.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
# Plot graph based on  features importance
plt.figure(figsize=(12,6))
plt.title("Feature importance")
ax = sns.barplot(y=fimp.index, x=fimp.values, orient='h', palette='viridis')

# %% [markdown]
# Absences are the strongest predictor of grades by a significant margin, with study time and parental support also playing crucial roles.

# %% [markdown]
# ## Data Modeling
# We create a machine learning model.

# %%
# Dictionary of classification models
classification_models = {
    "Logistic Regression": LogisticRegression(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
}

model_names = []
accuracies = []

# %%
# Train and evaluate each model
for name, clf in classification_models.items():
    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    model_names.append(name)
    accuracies.append(score)
    print(f"{name} accuracy: {score:.2f}")

# Create a DataFrame for model accuracies
df_models = pd.DataFrame({'Model': model_names, 'Accuracy': accuracies})
df_models.sort_values(by='Accuracy')
# Out:
# Logistic Regression accuracy: 0.73
# K-Nearest Neighbors accuracy: 0.67
# Support Vector Machine accuracy: 0.72
# Decision Tree accuracy: 0.63
# Random Forest accuracy: 0.71
# Gradient Boosting accuracy: 0.68
# AdaBoost accuracy: 0.66
# Gaussian Naive Bayes accuracy: 0.67
#                     Model  Accuracy
# 3           Decision Tree  0.625418
# 6                AdaBoost  0.660535
# 1     K-Nearest Neighbors  0.667224
# 7    Gaussian Naive Bayes  0.670569
# 5       Gradient Boosting  0.683946
# 4           Random Forest  0.710702
# 2  Support Vector Machine  0.720736
# 0     Logistic Regression  0.729097

# %%
# Plot model accuracies
plt.figure(figsize=(12,6))
ax = sns.barplot(data=df_models.sort_values(by='Accuracy', ascending=False), x='Model', y='Accuracy', palette='viridis')
plt.title('Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We can see that there are multiple models that would be effective for this task:
#
# * Logistic Regression
# * Support Vector Machine
# * Random Forest
# * Gradient Boosting

# %%
# Find the best model
best_index = accuracies.index(max(accuracies))
best_model_name = model_names[best_index]
best_model = classification_models[best_model_name]

print(f"The best model is: {best_model_name} with an accuracy of {accuracies[best_index]:.2f}")
# Out:
# The best model is: Logistic Regression with an accuracy of 0.73

# %% [markdown]
# ## Evaluation
# Model evaluation involves assessing the performance of our trained model using metrics such as confusion matrix, classification report, and accuracy score. These metrics help us understand how well our model is performing and where it might need improvement.

# %%
# Initialize and train model for the best model
best_model.fit(X_train, y_train)
model_score = best_model.score(X_test, y_test)
y_pred = best_model.predict(X_test)

# Calculate and plot the confusion matrix for the best 
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
print("Accuracy:",accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 72.90969899665552

# %%
# Generate classification report
report = classification_report(y_test,y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')

# %%
report_df_styled
# Out:
# <style type="text/css">
# #T_c3a2a_row0_col0, #T_c3a2a_row0_col1, #T_c3a2a_row0_col2, #T_c3a2a_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_c3a2a_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_c3a2a_row1_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_c3a2a_row1_col1 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_c3a2a_row1_col2, #T_c3a2a_row3_col0, #T_c3a2a_row6_col1 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_c3a2a_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_c3a2a_row2_col0 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_c3a2a_row2_col1 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_c3a2a_row2_col2 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_c3a2a_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_c3a2a_row3_col1 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_c3a2a_row3_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_c3a2a_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_c3a2a_row4_col0, #T_c3a2a_row4_col1, #T_c3a2a_row4_col2, #T_c3a2a_row6_col3, #T_c3a2a_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c3a2a_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_c3a2a_row5_col0 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_c3a2a_row5_col1, #T_c3a2a_row7_col1 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_c3a2a_row5_col2 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_c3a2a_row6_col0 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_c3a2a_row6_col2 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_c3a2a_row7_col0 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_c3a2a_row7_col2 {
#   background-color: #60ca60;
#   color: #000000;
# }
# </style>
# <table id="T_c3a2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3a2a_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c3a2a_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c3a2a_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c3a2a_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3a2a_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_c3a2a_row0_col0" class="data row0 col0" >0.250000</td>
#       <td id="T_c3a2a_row0_col1" class="data row0 col1" >0.037037</td>
#       <td id="T_c3a2a_row0_col2" class="data row0 col2" >0.064516</td>
#       <td id="T_c3a2a_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_c3a2a_row1_col0" class="data row1 col0" >0.539683</td>
#       <td id="T_c3a2a_row1_col1" class="data row1 col1" >0.507463</td>
#       <td id="T_c3a2a_row1_col2" class="data row1 col2" >0.523077</td>
#       <td id="T_c3a2a_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_c3a2a_row2_col0" class="data row2 col0" >0.503876</td>
#       <td id="T_c3a2a_row2_col1" class="data row2 col1" >0.663265</td>
#       <td id="T_c3a2a_row2_col2" class="data row2 col2" >0.572687</td>
#       <td id="T_c3a2a_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_c3a2a_row3_col0" class="data row3 col0" >0.597561</td>
#       <td id="T_c3a2a_row3_col1" class="data row3 col1" >0.475728</td>
#       <td id="T_c3a2a_row3_col2" class="data row3 col2" >0.529730</td>
#       <td id="T_c3a2a_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_c3a2a_row4_col0" class="data row4 col0" >0.896875</td>
#       <td id="T_c3a2a_row4_col1" class="data row4 col1" >0.947195</td>
#       <td id="T_c3a2a_row4_col2" class="data row4 col2" >0.921348</td>
#       <td id="T_c3a2a_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_c3a2a_row5_col0" class="data row5 col0" >0.729097</td>
#       <td id="T_c3a2a_row5_col1" class="data row5 col1" >0.729097</td>
#       <td id="T_c3a2a_row5_col2" class="data row5 col2" >0.729097</td>
#       <td id="T_c3a2a_row5_col3" class="data row5 col3" >0.729097</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_c3a2a_row6_col0" class="data row6 col0" >0.557599</td>
#       <td id="T_c3a2a_row6_col1" class="data row6 col1" >0.526138</td>
#       <td id="T_c3a2a_row6_col2" class="data row6 col2" >0.522272</td>
#       <td id="T_c3a2a_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c3a2a_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_c3a2a_row7_col0" class="data row7 col0" >0.711690</td>
#       <td id="T_c3a2a_row7_col1" class="data row7 col1" >0.729097</td>
#       <td id="T_c3a2a_row7_col2" class="data row7 col2" >0.713448</td>
#       <td id="T_c3a2a_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Precision
# Precision is the ratio of correctly predicted positive observations to the total predicted positives. It answers the question: Of all the items labeled as positive, how many are actually positive? Precision is crucial when the cost of a false positive is high.
#
# #### Recall
# Recall (also known as Sensitivity or True Positive Rate) is the ratio of correctly predicted positive observations to all observations in the actual class. It answers the question: Of all the actual positives, how many did we correctly identify? Recall is important when the cost of a false negative is high.
#
# #### F1-Score
# F1-Score is the weighted average of Precision and Recall. Therefore, it takes both false positives and false negatives into account. F1-Score is especially useful when you need a balance between Precision and Recall, and when you have an uneven class distribution.

# %%
# Initialize and train model for the SVM model
svm = SVC()
svm.fit(X_train, y_train)
model_score = svm.score(X_test, y_test)
y_pred = svm.predict(X_test)

# Calculate and plot the confusion matrix for the best 
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
print("Accuracy:",accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 72.07357859531773

# %%
# Generate classification report
report = classification_report(y_test,y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_284e2_row0_col0, #T_284e2_row0_col1, #T_284e2_row0_col2, #T_284e2_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_284e2_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_284e2_row1_col0 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_284e2_row1_col1, #T_284e2_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_284e2_row1_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_284e2_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_284e2_row2_col0 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_284e2_row2_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_284e2_row2_col2 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_284e2_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_284e2_row3_col0 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_284e2_row3_col1 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_284e2_row3_col2 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_284e2_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_284e2_row4_col0, #T_284e2_row4_col1, #T_284e2_row4_col2, #T_284e2_row6_col3, #T_284e2_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_284e2_row5_col0 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_284e2_row5_col1, #T_284e2_row7_col1 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_284e2_row5_col2 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_284e2_row6_col0 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_284e2_row6_col1 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_284e2_row6_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_284e2_row7_col0 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_284e2_row7_col2 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# </style>
# <table id="T_284e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_284e2_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_284e2_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_284e2_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_284e2_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_284e2_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_284e2_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_284e2_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_284e2_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_284e2_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_284e2_row1_col0" class="data row1 col0" >0.525424</td>
#       <td id="T_284e2_row1_col1" class="data row1 col1" >0.462687</td>
#       <td id="T_284e2_row1_col2" class="data row1 col2" >0.492063</td>
#       <td id="T_284e2_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_284e2_row2_col0" class="data row2 col0" >0.507937</td>
#       <td id="T_284e2_row2_col1" class="data row2 col1" >0.653061</td>
#       <td id="T_284e2_row2_col2" class="data row2 col2" >0.571429</td>
#       <td id="T_284e2_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_284e2_row3_col0" class="data row3 col0" >0.547170</td>
#       <td id="T_284e2_row3_col1" class="data row3 col1" >0.563107</td>
#       <td id="T_284e2_row3_col2" class="data row3 col2" >0.555024</td>
#       <td id="T_284e2_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_284e2_row4_col0" class="data row4 col0" >0.905537</td>
#       <td id="T_284e2_row4_col1" class="data row4 col1" >0.917492</td>
#       <td id="T_284e2_row4_col2" class="data row4 col2" >0.911475</td>
#       <td id="T_284e2_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_284e2_row5_col0" class="data row5 col0" >0.720736</td>
#       <td id="T_284e2_row5_col1" class="data row5 col1" >0.720736</td>
#       <td id="T_284e2_row5_col2" class="data row5 col2" >0.720736</td>
#       <td id="T_284e2_row5_col3" class="data row5 col3" >0.720736</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_284e2_row6_col0" class="data row6 col0" >0.497214</td>
#       <td id="T_284e2_row6_col1" class="data row6 col1" >0.519269</td>
#       <td id="T_284e2_row6_col2" class="data row6 col2" >0.505998</td>
#       <td id="T_284e2_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_284e2_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_284e2_row7_col0" class="data row7 col0" >0.695180</td>
#       <td id="T_284e2_row7_col1" class="data row7 col1" >0.720736</td>
#       <td id="T_284e2_row7_col2" class="data row7 col2" >0.706209</td>
#       <td id="T_284e2_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Hyperparameter Tuning
# Hyperparameters are the parameters that are not learned directly from the training data but are set before the training process begins. They control the training process and the structure of the machine learning models

# %%
# Define the model
model = SVC()

# Define evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# Define grid
grid = {'C': [0.1, 1, 10, 100, 1000],  
        'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
        'kernel': ['rbf']
       }

# Define search
search = GridSearchCV(estimator=model, param_grid=grid, cv=cv, scoring='accuracy', n_jobs=-1)

# Fit search to training data
result = search.fit(X_train, y_train)

# Summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.7512176701841506
# Best Hyperparameters: {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
# Initialize and train model
score = result.score(X_test, y_test)
y_pred = result.predict(X_test)

# Calculate and plot the confusion matrix
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_713b4_row0_col0, #T_713b4_row4_col1, #T_713b4_row4_col2, #T_713b4_row6_col3, #T_713b4_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_713b4_row0_col1, #T_713b4_row0_col2, #T_713b4_row3_col0, #T_713b4_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_713b4_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_713b4_row1_col0 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_713b4_row1_col1 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_713b4_row1_col2 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_713b4_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_713b4_row2_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_713b4_row2_col1 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_713b4_row2_col2 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_713b4_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_713b4_row3_col1 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_713b4_row3_col2 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_713b4_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_713b4_row4_col0 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_713b4_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_713b4_row5_col0 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_713b4_row5_col1, #T_713b4_row7_col1 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_713b4_row5_col2 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_713b4_row6_col0 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_713b4_row6_col1 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_713b4_row6_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_713b4_row7_col0 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_713b4_row7_col2 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# </style>
# <table id="T_713b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_713b4_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_713b4_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_713b4_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_713b4_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_713b4_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_713b4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_713b4_row0_col1" class="data row0 col1" >0.074074</td>
#       <td id="T_713b4_row0_col2" class="data row0 col2" >0.137931</td>
#       <td id="T_713b4_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_713b4_row1_col0" class="data row1 col0" >0.584416</td>
#       <td id="T_713b4_row1_col1" class="data row1 col1" >0.671642</td>
#       <td id="T_713b4_row1_col2" class="data row1 col2" >0.625000</td>
#       <td id="T_713b4_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_713b4_row2_col0" class="data row2 col0" >0.578947</td>
#       <td id="T_713b4_row2_col1" class="data row2 col1" >0.561224</td>
#       <td id="T_713b4_row2_col2" class="data row2 col2" >0.569948</td>
#       <td id="T_713b4_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_713b4_row3_col0" class="data row3 col0" >0.569106</td>
#       <td id="T_713b4_row3_col1" class="data row3 col1" >0.679612</td>
#       <td id="T_713b4_row3_col2" class="data row3 col2" >0.619469</td>
#       <td id="T_713b4_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_713b4_row4_col0" class="data row4 col0" >0.923588</td>
#       <td id="T_713b4_row4_col1" class="data row4 col1" >0.917492</td>
#       <td id="T_713b4_row4_col2" class="data row4 col2" >0.920530</td>
#       <td id="T_713b4_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_713b4_row5_col0" class="data row5 col0" >0.752508</td>
#       <td id="T_713b4_row5_col1" class="data row5 col1" >0.752508</td>
#       <td id="T_713b4_row5_col2" class="data row5 col2" >0.752508</td>
#       <td id="T_713b4_row5_col3" class="data row5 col3" >0.752508</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_713b4_row6_col0" class="data row6 col0" >0.731211</td>
#       <td id="T_713b4_row6_col1" class="data row6 col1" >0.580809</td>
#       <td id="T_713b4_row6_col2" class="data row6 col2" >0.574576</td>
#       <td id="T_713b4_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_713b4_row7_col0" class="data row7 col0" >0.771501</td>
#       <td id="T_713b4_row7_col1" class="data row7 col1" >0.752508</td>
#       <td id="T_713b4_row7_col2" class="data row7 col2" >0.742776</td>
#       <td id="T_713b4_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Reducing Dimensionality
# The process of reducing the number of independant variables under consideration, We know from our earlier investigation that the most important features are

# %%
fimp.head(3)
# Out:
# Absences           0.469150
# StudyTimeWeekly    0.191713
# ParentalSupport    0.069698
# dtype: float64

# %%
X_train = X_train[['Absences', 'StudyTimeWeekly', 'ParentalSupport']]
X_test = X_test[['Absences', 'StudyTimeWeekly', 'ParentalSupport']]

# %%
# Initialize and train model for the SVM model
svm = SVC()
svm.fit(X_train, y_train)
model_score = svm.score(X_test, y_test)
y_pred = svm.predict(X_test)

# Calculate and plot the confusion matrix for the best 
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_7aac3_row0_col0, #T_7aac3_row0_col1, #T_7aac3_row0_col2, #T_7aac3_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_7aac3_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_7aac3_row1_col0 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_7aac3_row1_col1 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_7aac3_row1_col2, #T_7aac3_row6_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_7aac3_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_7aac3_row2_col0 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_7aac3_row2_col1 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_7aac3_row2_col2 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_7aac3_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_7aac3_row3_col0 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_7aac3_row3_col1 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_7aac3_row3_col2 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_7aac3_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_7aac3_row4_col0, #T_7aac3_row4_col1, #T_7aac3_row4_col2, #T_7aac3_row6_col3, #T_7aac3_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7aac3_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_7aac3_row5_col0, #T_7aac3_row5_col1, #T_7aac3_row5_col2, #T_7aac3_row7_col1 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_7aac3_row6_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_7aac3_row6_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_7aac3_row7_col0 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_7aac3_row7_col2 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# </style>
# <table id="T_7aac3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aac3_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_7aac3_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_7aac3_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_7aac3_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aac3_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_7aac3_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_7aac3_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_7aac3_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_7aac3_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_7aac3_row1_col0" class="data row1 col0" >0.507937</td>
#       <td id="T_7aac3_row1_col1" class="data row1 col1" >0.477612</td>
#       <td id="T_7aac3_row1_col2" class="data row1 col2" >0.492308</td>
#       <td id="T_7aac3_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_7aac3_row2_col0" class="data row2 col0" >0.472441</td>
#       <td id="T_7aac3_row2_col1" class="data row2 col1" >0.612245</td>
#       <td id="T_7aac3_row2_col2" class="data row2 col2" >0.533333</td>
#       <td id="T_7aac3_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_7aac3_row3_col0" class="data row3 col0" >0.514286</td>
#       <td id="T_7aac3_row3_col1" class="data row3 col1" >0.524272</td>
#       <td id="T_7aac3_row3_col2" class="data row3 col2" >0.519231</td>
#       <td id="T_7aac3_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_7aac3_row4_col0" class="data row4 col0" >0.907591</td>
#       <td id="T_7aac3_row4_col1" class="data row4 col1" >0.907591</td>
#       <td id="T_7aac3_row4_col2" class="data row4 col2" >0.907591</td>
#       <td id="T_7aac3_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_7aac3_row5_col0" class="data row5 col0" >0.704013</td>
#       <td id="T_7aac3_row5_col1" class="data row5 col1" >0.704013</td>
#       <td id="T_7aac3_row5_col2" class="data row5 col2" >0.704013</td>
#       <td id="T_7aac3_row5_col3" class="data row5 col3" >0.704013</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_7aac3_row6_col0" class="data row6 col0" >0.480451</td>
#       <td id="T_7aac3_row6_col1" class="data row6 col1" >0.504344</td>
#       <td id="T_7aac3_row6_col2" class="data row6 col2" >0.490493</td>
#       <td id="T_7aac3_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7aac3_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_7aac3_row7_col0" class="data row7 col0" >0.682780</td>
#       <td id="T_7aac3_row7_col1" class="data row7 col1" >0.704013</td>
#       <td id="T_7aac3_row7_col2" class="data row7 col2" >0.691860</td>
#       <td id="T_7aac3_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Define the model
model = SVC()

# Define evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# Define grid
grid = {'C': [0.1, 1, 10, 100, 1000],  
        'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
        'kernel': ['rbf']
       }

# Define search
search = GridSearchCV(estimator=model, param_grid=grid, cv=cv, scoring='accuracy', n_jobs=-1)

# Fit search to training data
result = search.fit(X_train, y_train)

# Summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.7071756672873989
# Best Hyperparameters: {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
# Initialize and train model
score = result.score(X_test, y_test)
y_pred = result.predict(X_test)

# Calculate and plot the confusion matrix
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_ce44c_row0_col0, #T_ce44c_row4_col1, #T_ce44c_row4_col2, #T_ce44c_row6_col3, #T_ce44c_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ce44c_row0_col1, #T_ce44c_row0_col2, #T_ce44c_row2_col0, #T_ce44c_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ce44c_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_ce44c_row1_col0 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_ce44c_row1_col1, #T_ce44c_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_ce44c_row1_col2 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_ce44c_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_ce44c_row2_col1 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_ce44c_row2_col2 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_ce44c_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_ce44c_row3_col0 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_ce44c_row3_col1 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_ce44c_row3_col2 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_ce44c_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_ce44c_row4_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_ce44c_row5_col0 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_ce44c_row5_col1, #T_ce44c_row7_col1 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_ce44c_row5_col2 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_ce44c_row6_col0 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_ce44c_row6_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_ce44c_row6_col2 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_ce44c_row7_col0 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_ce44c_row7_col2 {
#   background-color: #60ca60;
#   color: #000000;
# }
# </style>
# <table id="T_ce44c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce44c_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_ce44c_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_ce44c_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_ce44c_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce44c_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_ce44c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ce44c_row0_col1" class="data row0 col1" >0.037037</td>
#       <td id="T_ce44c_row0_col2" class="data row0 col2" >0.071429</td>
#       <td id="T_ce44c_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_ce44c_row1_col0" class="data row1 col0" >0.533333</td>
#       <td id="T_ce44c_row1_col1" class="data row1 col1" >0.477612</td>
#       <td id="T_ce44c_row1_col2" class="data row1 col2" >0.503937</td>
#       <td id="T_ce44c_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_ce44c_row2_col0" class="data row2 col0" >0.500000</td>
#       <td id="T_ce44c_row2_col1" class="data row2 col1" >0.602041</td>
#       <td id="T_ce44c_row2_col2" class="data row2 col2" >0.546296</td>
#       <td id="T_ce44c_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_ce44c_row3_col0" class="data row3 col0" >0.526316</td>
#       <td id="T_ce44c_row3_col1" class="data row3 col1" >0.582524</td>
#       <td id="T_ce44c_row3_col2" class="data row3 col2" >0.552995</td>
#       <td id="T_ce44c_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_ce44c_row4_col0" class="data row4 col0" >0.901639</td>
#       <td id="T_ce44c_row4_col1" class="data row4 col1" >0.907591</td>
#       <td id="T_ce44c_row4_col2" class="data row4 col2" >0.904605</td>
#       <td id="T_ce44c_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_ce44c_row5_col0" class="data row5 col0" >0.714047</td>
#       <td id="T_ce44c_row5_col1" class="data row5 col1" >0.714047</td>
#       <td id="T_ce44c_row5_col2" class="data row5 col2" >0.714047</td>
#       <td id="T_ce44c_row5_col3" class="data row5 col3" >0.714047</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_ce44c_row6_col0" class="data row6 col0" >0.692258</td>
#       <td id="T_ce44c_row6_col1" class="data row6 col1" >0.521361</td>
#       <td id="T_ce44c_row6_col2" class="data row6 col2" >0.515853</td>
#       <td id="T_ce44c_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce44c_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_ce44c_row7_col0" class="data row7 col0" >0.734349</td>
#       <td id="T_ce44c_row7_col1" class="data row7 col1" >0.714047</td>
#       <td id="T_ce44c_row7_col2" class="data row7 col2" >0.702815</td>
#       <td id="T_ce44c_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Conclusion
# A Support Vector Machine initially predicts students' grades with 75.3% accuracy on the test set without hyperparameter tuning. When dimensionality is reduced to just three key features—
# * Absences,
# * StudyTimeWeekly,
# * and ParentalSupport.
# the accuracy drops to 71.4%.
#
# Including all features improves accuracy, but at a higher resource cost.
#
# A noteworthy takeaway emerges: to excel academically in high school, attending classes and studying the material are crucial. Parental support significantly influences student success, though it's a factor beyond students' control.
