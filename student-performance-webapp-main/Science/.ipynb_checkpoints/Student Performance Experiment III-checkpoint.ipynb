# %% [markdown]
# # Student Performance Analysis and Prediction
#
# ## Introduction
# This project aims to analyze and predict student performance based on various factors, including demographic details, study habits, parental involvement, and participation in extracurricular activities. By understanding these influences, we can identify patterns and provide actionable insights to improve educational outcomes.
#
#
# ## Table of Contents
#
# * Student Information
# * Demographic Details
# * Study Habits
# * Parental Involvement
# * Extracurricular Activities
# * Academic Performance
# * Target Variable: Grade Class
#
# 1. ### Student Information
# * StudentID: A unique identifier assigned to each student (1001 to 3392).
#
# 2. ### Demographic Details
# * Age: The age of the students ranges from 15 to 18 years.
# * Gender: Gender of the students, where 0 represents Male and 1 represents Female.
# * Ethnicity: The ethnicity of the students, coded as follows:
# >0: Caucasian
# 1: African American
# 2: Asian
# 3: Other
# * ParentalEducation: The education level of the parents, coded as follows:
# > 0: None
# 1: High School
# 2: Some College
# 3: Bachelor's
# 4: Higher
#
# 3. ### Study Habits
# * StudyTimeWeekly: Weekly study time in hours, ranging from 0 to 20.
# * Absences: Number of absences during the school year, ranging from 0 to 30.
# * Tutoring: Tutoring status, where 0 indicates No and 1 indicates Yes.
#
# 4. ### Parental Involvement
# * ParentalSupport: The level of parental support, coded as follows:
# > 0: None
# 1: Low
# 2: Moderate
# 3: High
# 4: Very High
#
# 5. ### Extracurricular Activities
# * Extracurricular: Participation in extracurricular activities, where 0 indicates No and 1 indicates Yes.
# * Sports: Participation in sports, where 0 indicates No and 1 indicates Yes.
# * Music: Participation in music activities, where 0 indicates No and 1 indicates Yes.
# * Volunteering: Participation in volunteering, where 0 indicates No and 1 indicates Yes.
#
# 6. ### Academic Performance
# * GPA: Grade Point Average on a scale from 2.0 to 4.0, influenced by study habits, parental involvement, and extracurricular activities.
# Target Variable: Grade Class
# * GradeClass: Classification of students' grades based on GPA:
# >0: 'A' (GPA >= 3.5)
# 1: 'B' (3.0 <= GPA < 3.5)
# 2: 'C' (2.5 <= GPA < 3.0)
# 3: 'D' (2.0 <= GPA < 2.5)
# 4: 'F' (GPA < 2.0)

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Libraries Importation
# We begin by importing essential libraries for data manipulation, visualization, and modeling. These include pandas, numpy, matplotlib, seaborn, and several Scikit-learn modules.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, f1_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import RepeatedStratifiedKFold, RandomizedSearchCV, GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
import pickle
from scipy.stats import loguniform
from xgboost import XGBClassifier

# Set plot style
sns.set(style='whitegrid')

# %% [markdown]
# ## Data Collection and Loading
# The dataset is loaded into a pandas DataFrame. This dataset contains various attributes related to students, such as demographic details, study habits, parental involvement, extracurricular activities, and academic performance.

# %%
# Load the dataset
file_path = 'Student_performance_data.csv'
data = pd.read_csv(file_path)

# %%
# Display the first few rows of the dataset
display(data.head())
display(data.tail())
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# 2387             0  3.455509         0.0
# 2388             0  3.279150         4.0
# 2389             1  1.142333         2.0
# 2390             0  1.803297         1.0
# 2391             1  2.140014         1.0

# %% [markdown]
# ## Data Cleaning
# Data cleaning involves handling missing values and ensuring that the data types of the features are appropriate. This step is crucial for ensuring the accuracy and reliability of our analysis and modeling.

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
# Convert categorical columns to appropriate data types
data['Gender'] = data['Gender'].astype('category')
data['Ethnicity'] = data['Ethnicity'].astype('category')
data['ParentalEducation'] = data['ParentalEducation'].astype('category')
data['Tutoring'] = data['Tutoring'].astype('category')
data['ParentalSupport'] = data['ParentalSupport'].astype('category')
data['Extracurricular'] = data['Extracurricular'].astype('category')
data['Sports'] = data['Sports'].astype('category')
data['Music'] = data['Music'].astype('category')
data['Volunteering'] = data['Volunteering'].astype('category')
data['GradeClass'] = data['GradeClass'].astype('category')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Exploratory Data Analysis helps us understand the distribution and relationships within the data. We use visualizations like correlation heatmaps and distribution plots to identify patterns and insights that will guide our modeling approach.

# %%
# Summary statistics
data.describe()
# Out:
#          StudentID          Age  StudyTimeWeekly     Absences          GPA
# count  2392.000000  2392.000000      2392.000000  2392.000000  2392.000000
# mean   2196.500000    16.468645         9.771992    14.541388     1.906186
# std     690.655244     1.123798         5.652774     8.467417     0.915156
# min    1001.000000    15.000000         0.001057     0.000000     0.000000
# 25%    1598.750000    15.000000         5.043079     7.000000     1.174803
# 50%    2196.500000    16.000000         9.705363    15.000000     1.893393
# 75%    2794.250000    17.000000        14.408410    22.000000     2.622216
# max    3392.000000    18.000000        19.978094    29.000000     4.000000

# %% [markdown]
# ### What is the distribution of GPA among students?

# %%
# Plot the distribution of GPA
plt.figure(figsize=(10, 6))
sns.histplot(data['GPA'], kde=True, bins=30, color='blue')
plt.title('Distribution of GPA')
plt.xlabel('GPA')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar chart for the 'GradeClass' column
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='GradeClass', data=data, palette='viridis')

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

for bar, color in zip(ax.patches, colors):
    bar.set_color(color)

# Custom Legend
legend_labels = ['Grade A', 'Grade B', 'Grade C', 'Grade D', 'Grade F']
custom_legend = [plt.Line2D([0], [0], color=color, lw=4) for color in colors]
plt.legend(custom_legend, legend_labels, title='Grade Classes')

# Adding titles and labels
plt.title('Grade Class Distribution of Students')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ### What is the average GPA and grade for each gender?

# %%
average_gpa_gender = data.groupby('Gender')['GPA'].mean()
average_gpa_gender
# Out:
# Gender
# 0    1.918679
# 1    1.894225
# Name: GPA, dtype: float64

# %%
# Plotting the average GPA by Parental Education Level

plt.figure(figsize=(12, 6))
average_gpa_gender.plot(kind='bar')
plt.title('Average GPA by Gender')
plt.xlabel('Gender')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Mapping of codes to labels
gender_labels = {
    0: 'Male',
    1: 'Female',
}
# Plot the relationship between GradeClass and Gender with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='Gender', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Gender')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in gender_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %% [markdown]
# ### How does parental education level and Parental Support affect student GPA?

# %%
average_gpa_parentaled = data.groupby('ParentalEducation')['GPA'].mean()
average_gpa_parentaled
# Out:
# ParentalEducation
# 0    1.893045
# 1    1.944022
# 2    1.929881
# 3    1.809082
# 4    1.815812
# Name: GPA, dtype: float64

# %%
# Plotting the average GPA by Parental Education Level

plt.figure(figsize=(12, 6))
average_gpa_parentaled.plot(kind='bar')
plt.title('Average GPA by Parental Education Level')
plt.xlabel('Parental Education Level')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Mapping of codes to labels
parental_support_labels = {
    0: 'None',
    1: 'Low',
    2: 'Moderate',
    3: 'High',
    4: 'Very High'
}

# Plot the relationship between GradeClass and ParentalSupport with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='ParentalSupport', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Parental Support')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in parental_support_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %% [markdown]
# ### Do students who participate in extracurricular activities have higher GPAs?

# %%
average_gpa_extracurricular = data.groupby('Extracurricular')['GPA'].mean()
average_gpa_extracurricular
# Out:
# Extracurricular
# 0    1.838316
# 1    2.015357
# Name: GPA, dtype: float64

# %%
plt.figure(figsize=(12, 6))
average_gpa_extracurricular.plot(kind='bar')
plt.title('Average GPA by Extracurricular Activity')
plt.xlabel('Extracurricular Activity')
plt.ylabel('Average GPA')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Mapping of codes to labels
extracurricular_labels = {
    0: 'No',
    1: 'Yes',
}

# Plot the relationship between GradeClass and ParentalSupport with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='Extracurricular', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Extracurricular Activity')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in extracurricular_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %% [markdown]
# ### What is the distribution of study time and absences among students?

# %%
# Plot the distribution of study time
plt.figure(figsize=(10, 6))
sns.histplot(data['StudyTimeWeekly'], kde=True, bins=30, color='blue')
plt.title('Distribution of Study Time')
plt.xlabel('Study Time')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of A
plt.figure(figsize=(10, 6))
sns.histplot(data['Absences'], kde=True, bins=30, color='blue')
plt.title('Distribution of Absences')
plt.xlabel('Absences')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Is there a relationship between study time, Absences, Tutorinng and GPA?

# %%
# Plot Study Time vs GPA
plt.figure(figsize=(10, 6))
sns.regplot(data=data, x='StudyTimeWeekly', y='GPA', line_kws={'color': 'red'})
plt.title('Study Time vs GPA')
plt.xlabel('Study Time Weekly (hours)')
plt.ylabel('GPA')
plt.show()

# %%
correlation_study_time_gpa = data['StudyTimeWeekly'].corr(data['GPA'])
display(correlation_study_time_gpa)
# Out:
# np.float64(0.17927512685608818)

# %%
# Plot Absences vs GPA
plt.figure(figsize=(10, 6))
sns.regplot(x='Absences', y='GPA', data=data, line_kws={'color': 'red'})
plt.title('Absences vs GPA')
plt.xlabel('Number of Absences')
plt.ylabel('GPA')
plt.show()

# %%
correlation_absences_gpa = data['Absences'].corr(data['GPA'])
display(correlation_absences_gpa)
# Out:
# np.float64(-0.9193135764208643)

# %%
# Mapping of codes to labels
tutoring_labels = {
    0: 'No',
    1: 'Yes',
}

# Plot the relationship between GradeClass and Tutoring with custom legend
plt.figure(figsize=(12, 6))
sns.countplot(x='GradeClass', hue='Tutoring', data=data, palette='viridis')
plt.title('Relationship between Grade Class and Tutoring')
plt.xlabel('Grade Class')
plt.ylabel('Count')

# Create custom legend
legend_labels = [f'{key}: {value}' for key, value in tutoring_labels.items()]
plt.legend(title='Parental Support', labels=legend_labels)

plt.show()

# %%
# Plot correlation heatmap
plt.figure(figsize=(14, 8))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Analysis Summary
#
# The analysis of the student performance dataset reveals significant influences on GPA:
#
# - **Increased Study Time**: Students who spend more time studying each week tend to have higher GPAs.
# - **Participation in Extracurricular Activities**: Engagement in extracurricular activities such as sports, music, and volunteering is positively correlated with GPA.
# - **Attendance**: Higher numbers of absences are associated with lower GPAs.
#
# These insights underscore the importance of consistent attendance, and balanced extracurricular engagement in fostering academic success.

# %% [markdown]
# ## Train-Test Split And Slaced
# To evaluate our model's performance, we split the data into training and testing sets. This allows us to train the model on one portion of the data and test it on another, ensuring that the model generalizes well to unseen data.

# %%
X = data.drop(columns=['GradeClass', 'GPA', 'StudentID', 'Age'])
y = data['GradeClass']

# Splitting the data into training and testing sets (e.g., 75% train, 25% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Feature Selection
# In this step, we select the relevant features for our model. We drop unnecessary columns such as `StudentID`, `GPA`, `Age` and the target variable `GradeClass` from the feature set `X`, and define the target variable `y`.

# %%
# Train on the data to determine the feature importance using RandomForest Algorithm 
clf = RandomForestClassifier(random_state = 42)
clf = clf.fit(X, y)

fimp = pd.Series(data=clf.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
# Plot graph based on  features importance
plt.figure(figsize=(12,6))
plt.title("Feature importance")
ax = sns.barplot(y=fimp.index, x=fimp.values, orient='h', palette='viridis')

# %% [markdown]
# Absences are the strongest predictor of grades by a significant margin, with study time and parental support also playing crucial roles.

# %% [markdown]
# ## Data Modeling
# We create a machine learning model.

# %%
# Dictionary of classification models
classification_models = {
    "Logistic Regression": LogisticRegression(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
}

model_names = []
accuracies = []

# %%
# Train and evaluate each model
for name, clf in classification_models.items():
    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    model_names.append(name)
    accuracies.append(score)
    print(f"{name} accuracy: {score:.2f}")

# Create a DataFrame for model accuracies
df_models = pd.DataFrame({'Model': model_names, 'Accuracy': accuracies})
df_models.sort_values(by='Accuracy')
# Out:
# Logistic Regression accuracy: 0.73
# K-Nearest Neighbors accuracy: 0.58
# Support Vector Machine accuracy: 0.72
# Decision Tree accuracy: 0.63
# Random Forest accuracy: 0.70
# Gradient Boosting accuracy: 0.68
# AdaBoost accuracy: 0.66
# Gaussian Naive Bayes accuracy: 0.67
#                     Model  Accuracy
# 1     K-Nearest Neighbors  0.575251
# 3           Decision Tree  0.625418
# 6                AdaBoost  0.660535
# 7    Gaussian Naive Bayes  0.670569
# 5       Gradient Boosting  0.683946
# 4           Random Forest  0.704013
# 2  Support Vector Machine  0.722408
# 0     Logistic Regression  0.730769

# %%
# Plot model accuracies
plt.figure(figsize=(12,6))
ax = sns.barplot(data=df_models.sort_values(by='Accuracy', ascending=False), x='Model', y='Accuracy', palette='viridis')
plt.title('Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We can see that there are multiple models that would be effective for this task:
#
# * Logistic Regression
# * Support Vector Machine
# * Random Forest
# * Gradient Boosting

# %%
# Find the best model
best_index = accuracies.index(max(accuracies))
best_model_name = model_names[best_index]
best_model = classification_models[best_model_name]

print(f"The best model is: {best_model_name} with an accuracy of {accuracies[best_index]:.2f}")
# Out:
# The best model is: Logistic Regression with an accuracy of 0.73

# %% [markdown]
# ## Evaluation
# Model evaluation involves assessing the performance of our trained model using metrics such as confusion matrix, classification report, and accuracy score. These metrics help us understand how well our model is performing and where it might need improvement.

# %%
# Initialize and train model for the best model
best_model.fit(X_train, y_train)
model_score = best_model.score(X_test, y_test)
y_pred = best_model.predict(X_test)

# Calculate and plot the confusion matrix for the best 
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
print("Accuracy:",accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 73.07692307692307

# %%
# Generate classification report
report = classification_report(y_test,y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')

# %%
report_df_styled
# Out:
# <style type="text/css">
# #T_eeeb4_row0_col0, #T_eeeb4_row0_col1, #T_eeeb4_row0_col2, #T_eeeb4_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_eeeb4_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_eeeb4_row1_col0 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_eeeb4_row1_col1 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row1_col2 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_eeeb4_row2_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_eeeb4_row2_col1 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_eeeb4_row2_col2 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_eeeb4_row3_col0 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_eeeb4_row3_col1 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row3_col2 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_eeeb4_row4_col0, #T_eeeb4_row4_col1, #T_eeeb4_row4_col2, #T_eeeb4_row6_col3, #T_eeeb4_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_eeeb4_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_eeeb4_row5_col0 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_eeeb4_row5_col1, #T_eeeb4_row7_col1 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_eeeb4_row5_col2 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row6_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_eeeb4_row6_col1 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_eeeb4_row6_col2 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_eeeb4_row7_col0 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_eeeb4_row7_col2 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eeeb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eeeb4_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_eeeb4_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_eeeb4_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_eeeb4_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeeb4_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_eeeb4_row0_col0" class="data row0 col0" >0.500000</td>
#       <td id="T_eeeb4_row0_col1" class="data row0 col1" >0.185185</td>
#       <td id="T_eeeb4_row0_col2" class="data row0 col2" >0.270270</td>
#       <td id="T_eeeb4_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_eeeb4_row1_col0" class="data row1 col0" >0.574074</td>
#       <td id="T_eeeb4_row1_col1" class="data row1 col1" >0.462687</td>
#       <td id="T_eeeb4_row1_col2" class="data row1 col2" >0.512397</td>
#       <td id="T_eeeb4_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_eeeb4_row2_col0" class="data row2 col0" >0.504000</td>
#       <td id="T_eeeb4_row2_col1" class="data row2 col1" >0.642857</td>
#       <td id="T_eeeb4_row2_col2" class="data row2 col2" >0.565022</td>
#       <td id="T_eeeb4_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_eeeb4_row3_col0" class="data row3 col0" >0.579545</td>
#       <td id="T_eeeb4_row3_col1" class="data row3 col1" >0.495146</td>
#       <td id="T_eeeb4_row3_col2" class="data row3 col2" >0.534031</td>
#       <td id="T_eeeb4_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_eeeb4_row4_col0" class="data row4 col0" >0.894081</td>
#       <td id="T_eeeb4_row4_col1" class="data row4 col1" >0.947195</td>
#       <td id="T_eeeb4_row4_col2" class="data row4 col2" >0.919872</td>
#       <td id="T_eeeb4_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_eeeb4_row5_col0" class="data row5 col0" >0.730769</td>
#       <td id="T_eeeb4_row5_col1" class="data row5 col1" >0.730769</td>
#       <td id="T_eeeb4_row5_col2" class="data row5 col2" >0.730769</td>
#       <td id="T_eeeb4_row5_col3" class="data row5 col3" >0.730769</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_eeeb4_row6_col0" class="data row6 col0" >0.610340</td>
#       <td id="T_eeeb4_row6_col1" class="data row6 col1" >0.546614</td>
#       <td id="T_eeeb4_row6_col2" class="data row6 col2" >0.560319</td>
#       <td id="T_eeeb4_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eeeb4_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_eeeb4_row7_col0" class="data row7 col0" >0.722332</td>
#       <td id="T_eeeb4_row7_col1" class="data row7 col1" >0.730769</td>
#       <td id="T_eeeb4_row7_col2" class="data row7 col2" >0.720278</td>
#       <td id="T_eeeb4_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Precision
# Precision is the ratio of correctly predicted positive observations to the total predicted positives. It answers the question: Of all the items labeled as positive, how many are actually positive? Precision is crucial when the cost of a false positive is high.
#
# #### Recall
# Recall (also known as Sensitivity or True Positive Rate) is the ratio of correctly predicted positive observations to all observations in the actual class. It answers the question: Of all the actual positives, how many did we correctly identify? Recall is important when the cost of a false negative is high.
#
# #### F1-Score
# F1-Score is the weighted average of Precision and Recall. Therefore, it takes both false positives and false negatives into account. F1-Score is especially useful when you need a balance between Precision and Recall, and when you have an uneven class distribution.

# %%
# Initialize and train model for the SVM model
svm = SVC()
svm.fit(X_train, y_train)
model_score = svm.score(X_test, y_test)
y_pred = svm.predict(X_test)

# Calculate and plot the confusion matrix for the best 
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
print("Accuracy:",accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 72.24080267558529

# %%
# Generate classification report
report = classification_report(y_test,y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_2c15a_row0_col0 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_2c15a_row0_col1, #T_2c15a_row0_col2, #T_2c15a_row2_col0, #T_2c15a_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2c15a_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_2c15a_row1_col0 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_2c15a_row1_col1 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_2c15a_row1_col2 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_2c15a_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_2c15a_row2_col1 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_2c15a_row2_col2 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_2c15a_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_2c15a_row3_col0 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_2c15a_row3_col1 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_2c15a_row3_col2 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_2c15a_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_2c15a_row4_col0, #T_2c15a_row4_col1, #T_2c15a_row4_col2, #T_2c15a_row6_col3, #T_2c15a_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2c15a_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_2c15a_row5_col0 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_2c15a_row5_col1, #T_2c15a_row7_col1 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_2c15a_row5_col2 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_2c15a_row6_col0 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_2c15a_row6_col1 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_2c15a_row6_col2 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_2c15a_row7_col0 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_2c15a_row7_col2 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2c15a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c15a_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_2c15a_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_2c15a_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_2c15a_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c15a_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_2c15a_row0_col0" class="data row0 col0" >0.800000</td>
#       <td id="T_2c15a_row0_col1" class="data row0 col1" >0.148148</td>
#       <td id="T_2c15a_row0_col2" class="data row0 col2" >0.250000</td>
#       <td id="T_2c15a_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_2c15a_row1_col0" class="data row1 col0" >0.625000</td>
#       <td id="T_2c15a_row1_col1" class="data row1 col1" >0.447761</td>
#       <td id="T_2c15a_row1_col2" class="data row1 col2" >0.521739</td>
#       <td id="T_2c15a_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_2c15a_row2_col0" class="data row2 col0" >0.492188</td>
#       <td id="T_2c15a_row2_col1" class="data row2 col1" >0.642857</td>
#       <td id="T_2c15a_row2_col2" class="data row2 col2" >0.557522</td>
#       <td id="T_2c15a_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_2c15a_row3_col0" class="data row3 col0" >0.546392</td>
#       <td id="T_2c15a_row3_col1" class="data row3 col1" >0.514563</td>
#       <td id="T_2c15a_row3_col2" class="data row3 col2" >0.530000</td>
#       <td id="T_2c15a_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_2c15a_row4_col0" class="data row4 col0" >0.881250</td>
#       <td id="T_2c15a_row4_col1" class="data row4 col1" >0.930693</td>
#       <td id="T_2c15a_row4_col2" class="data row4 col2" >0.905297</td>
#       <td id="T_2c15a_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_2c15a_row5_col0" class="data row5 col0" >0.722408</td>
#       <td id="T_2c15a_row5_col1" class="data row5 col1" >0.722408</td>
#       <td id="T_2c15a_row5_col2" class="data row5 col2" >0.722408</td>
#       <td id="T_2c15a_row5_col3" class="data row5 col3" >0.722408</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_2c15a_row6_col0" class="data row6 col0" >0.668966</td>
#       <td id="T_2c15a_row6_col1" class="data row6 col1" >0.536805</td>
#       <td id="T_2c15a_row6_col2" class="data row6 col2" >0.552912</td>
#       <td id="T_2c15a_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2c15a_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_2c15a_row7_col0" class="data row7 col0" >0.727436</td>
#       <td id="T_2c15a_row7_col1" class="data row7 col1" >0.722408</td>
#       <td id="T_2c15a_row7_col2" class="data row7 col2" >0.711101</td>
#       <td id="T_2c15a_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Hyperparameter Tuning
# Hyperparameters are the parameters that are not learned directly from the training data but are set before the training process begins. They control the training process and the structure of the machine learning models

# %%
# Define the model
model = SVC()

# Define evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# Define grid
grid = {'C': [0.1, 1, 10, 100, 1000],  
        'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
        'kernel': ['rbf']
       }

# Define search
search = GridSearchCV(estimator=model, param_grid=grid, cv=cv, scoring='accuracy', n_jobs=-1)

# Fit search to training data
result = search.fit(X_train, y_train)

# Summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.748055038278502
# Best Hyperparameters: {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
# Initialize and train model
score = result.score(X_test, y_test)
y_pred = result.predict(X_test)

# Calculate and plot the confusion matrix
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_537cd_row0_col0, #T_537cd_row0_col1, #T_537cd_row0_col2, #T_537cd_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_537cd_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_537cd_row1_col0 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_537cd_row1_col1 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_537cd_row1_col2 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_537cd_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_537cd_row2_col0, #T_537cd_row3_col0, #T_537cd_row6_col1 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_537cd_row2_col1 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_537cd_row2_col2 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_537cd_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_537cd_row3_col1 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_537cd_row3_col2 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_537cd_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_537cd_row4_col0, #T_537cd_row4_col1, #T_537cd_row4_col2, #T_537cd_row6_col3, #T_537cd_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_537cd_row4_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_537cd_row5_col0 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_537cd_row5_col1, #T_537cd_row7_col1 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_537cd_row5_col2 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_537cd_row6_col0 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_537cd_row6_col2 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_537cd_row7_col0 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_537cd_row7_col2 {
#   background-color: #7ad151;
#   color: #000000;
# }
# </style>
# <table id="T_537cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_537cd_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_537cd_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_537cd_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_537cd_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_537cd_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_537cd_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_537cd_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_537cd_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_537cd_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_537cd_row1_col0" class="data row1 col0" >0.593750</td>
#       <td id="T_537cd_row1_col1" class="data row1 col1" >0.567164</td>
#       <td id="T_537cd_row1_col2" class="data row1 col2" >0.580153</td>
#       <td id="T_537cd_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_537cd_row2_col0" class="data row2 col0" >0.564103</td>
#       <td id="T_537cd_row2_col1" class="data row2 col1" >0.673469</td>
#       <td id="T_537cd_row2_col2" class="data row2 col2" >0.613953</td>
#       <td id="T_537cd_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_537cd_row3_col0" class="data row3 col0" >0.564103</td>
#       <td id="T_537cd_row3_col1" class="data row3 col1" >0.640777</td>
#       <td id="T_537cd_row3_col2" class="data row3 col2" >0.600000</td>
#       <td id="T_537cd_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_537cd_row4_col0" class="data row4 col0" >0.920000</td>
#       <td id="T_537cd_row4_col1" class="data row4 col1" >0.910891</td>
#       <td id="T_537cd_row4_col2" class="data row4 col2" >0.915423</td>
#       <td id="T_537cd_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_537cd_row5_col0" class="data row5 col0" >0.745819</td>
#       <td id="T_537cd_row5_col1" class="data row5 col1" >0.745819</td>
#       <td id="T_537cd_row5_col2" class="data row5 col2" >0.745819</td>
#       <td id="T_537cd_row5_col3" class="data row5 col3" >0.745819</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_537cd_row6_col0" class="data row6 col0" >0.528391</td>
#       <td id="T_537cd_row6_col1" class="data row6 col1" >0.558460</td>
#       <td id="T_537cd_row6_col2" class="data row6 col2" >0.541906</td>
#       <td id="T_537cd_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_537cd_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_537cd_row7_col0" class="data row7 col0" >0.722284</td>
#       <td id="T_537cd_row7_col1" class="data row7 col1" >0.745819</td>
#       <td id="T_537cd_row7_col2" class="data row7 col2" >0.732794</td>
#       <td id="T_537cd_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Reducing Dimensionality
# The process of reducing the number of independant variables under consideration, We know from our earlier investigation that the most important features are

# %%
fimp.head(3)
# Out:
# Absences           0.469150
# StudyTimeWeekly    0.191713
# ParentalSupport    0.069698
# dtype: float64

# %%
X = data.drop(columns=['GradeClass', 'GPA', 'StudentID', 'Age'])
y = data['GradeClass']

# Splitting the data into training and testing sets (e.g., 75% train, 25% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)

X_train = X_train[['Absences', 'StudyTimeWeekly', 'ParentalSupport']]
X_test = X_test[['Absences', 'StudyTimeWeekly', 'ParentalSupport']]

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize and train model for the SVM model
svm = SVC()
svm.fit(X_train, y_train)
model_score = svm.score(X_test, y_test)
y_pred = svm.predict(X_test)

# Calculate and plot the confusion matrix for the best 
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_76e97_row0_col0, #T_76e97_row4_col1, #T_76e97_row4_col2, #T_76e97_row6_col3, #T_76e97_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_76e97_row0_col1, #T_76e97_row0_col2, #T_76e97_row2_col0, #T_76e97_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_76e97_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_76e97_row1_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_76e97_row1_col1, #T_76e97_row1_col2 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_76e97_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_76e97_row2_col1 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_76e97_row2_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_76e97_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_76e97_row3_col0 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_76e97_row3_col1 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_76e97_row3_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_76e97_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_76e97_row4_col0 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_76e97_row4_col3, #T_76e97_row6_col2 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_76e97_row5_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_76e97_row5_col1, #T_76e97_row7_col1 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_76e97_row5_col2 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_76e97_row6_col0 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_76e97_row6_col1 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_76e97_row7_col0 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_76e97_row7_col2 {
#   background-color: #58c765;
#   color: #000000;
# }
# </style>
# <table id="T_76e97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76e97_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_76e97_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_76e97_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_76e97_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76e97_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_76e97_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_76e97_row0_col1" class="data row0 col1" >0.074074</td>
#       <td id="T_76e97_row0_col2" class="data row0 col2" >0.137931</td>
#       <td id="T_76e97_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_76e97_row1_col0" class="data row1 col0" >0.566667</td>
#       <td id="T_76e97_row1_col1" class="data row1 col1" >0.507463</td>
#       <td id="T_76e97_row1_col2" class="data row1 col2" >0.535433</td>
#       <td id="T_76e97_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_76e97_row2_col0" class="data row2 col0" >0.486726</td>
#       <td id="T_76e97_row2_col1" class="data row2 col1" >0.561224</td>
#       <td id="T_76e97_row2_col2" class="data row2 col2" >0.521327</td>
#       <td id="T_76e97_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_76e97_row3_col0" class="data row3 col0" >0.521368</td>
#       <td id="T_76e97_row3_col1" class="data row3 col1" >0.592233</td>
#       <td id="T_76e97_row3_col2" class="data row3 col2" >0.554545</td>
#       <td id="T_76e97_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_76e97_row4_col0" class="data row4 col0" >0.901961</td>
#       <td id="T_76e97_row4_col1" class="data row4 col1" >0.910891</td>
#       <td id="T_76e97_row4_col2" class="data row4 col2" >0.906404</td>
#       <td id="T_76e97_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_76e97_row5_col0" class="data row5 col0" >0.715719</td>
#       <td id="T_76e97_row5_col1" class="data row5 col1" >0.715719</td>
#       <td id="T_76e97_row5_col2" class="data row5 col2" >0.715719</td>
#       <td id="T_76e97_row5_col3" class="data row5 col3" >0.715719</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_76e97_row6_col0" class="data row6 col0" >0.695344</td>
#       <td id="T_76e97_row6_col1" class="data row6 col1" >0.529177</td>
#       <td id="T_76e97_row6_col2" class="data row6 col2" >0.531128</td>
#       <td id="T_76e97_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76e97_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_76e97_row7_col0" class="data row7 col0" >0.735219</td>
#       <td id="T_76e97_row7_col1" class="data row7 col1" >0.715719</td>
#       <td id="T_76e97_row7_col2" class="data row7 col2" >0.706433</td>
#       <td id="T_76e97_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Define the model
model = SVC()

# Define evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# Define grid
grid = {'C': [0.1, 1, 10, 100, 1000],  
        'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
        'kernel': ['rbf']
       }

# Define search
search = GridSearchCV(estimator=model, param_grid=grid, cv=cv, scoring='accuracy', n_jobs=-1)

# Fit search to training data
result = search.fit(X_train, y_train)

# Summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.7017804676184565
# Best Hyperparameters: {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
# Initialize and train model
score = result.score(X_test, y_test)
y_pred = result.predict(X_test)

# Calculate and plot the confusion matrix
score = round(accuracy_score(y_test, y_pred), 3)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f")
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy Score: {0}'.format(score), size=15)
plt.show()

# %%
# Generate classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Display the DataFrame using Pandas styling
report_df_styled = report_df.style.background_gradient(cmap='viridis')
report_df_styled
# Out:
# <style type="text/css">
# #T_bc1d1_row0_col0 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_bc1d1_row0_col1, #T_bc1d1_row0_col2, #T_bc1d1_row2_col0, #T_bc1d1_row5_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_bc1d1_row0_col3 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_bc1d1_row1_col0 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_bc1d1_row1_col1 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_bc1d1_row1_col2, #T_bc1d1_row2_col2 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_bc1d1_row1_col3 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_bc1d1_row2_col1, #T_bc1d1_row4_col3, #T_bc1d1_row6_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_bc1d1_row2_col3 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_bc1d1_row3_col0 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_bc1d1_row3_col1 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_bc1d1_row3_col2 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_bc1d1_row3_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_bc1d1_row4_col0, #T_bc1d1_row4_col1, #T_bc1d1_row4_col2, #T_bc1d1_row6_col3, #T_bc1d1_row7_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_bc1d1_row5_col0 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_bc1d1_row5_col1, #T_bc1d1_row7_col1 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_bc1d1_row5_col2 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_bc1d1_row6_col0 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_bc1d1_row6_col2 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_bc1d1_row7_col0 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_bc1d1_row7_col2 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc1d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc1d1_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_bc1d1_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_bc1d1_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_bc1d1_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc1d1_level0_row0" class="row_heading level0 row0" >0.0</th>
#       <td id="T_bc1d1_row0_col0" class="data row0 col0" >0.666667</td>
#       <td id="T_bc1d1_row0_col1" class="data row0 col1" >0.148148</td>
#       <td id="T_bc1d1_row0_col2" class="data row0 col2" >0.242424</td>
#       <td id="T_bc1d1_row0_col3" class="data row0 col3" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row1" class="row_heading level0 row1" >1.0</th>
#       <td id="T_bc1d1_row1_col0" class="data row1 col0" >0.550000</td>
#       <td id="T_bc1d1_row1_col1" class="data row1 col1" >0.492537</td>
#       <td id="T_bc1d1_row1_col2" class="data row1 col2" >0.519685</td>
#       <td id="T_bc1d1_row1_col3" class="data row1 col3" >67.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row2" class="row_heading level0 row2" >2.0</th>
#       <td id="T_bc1d1_row2_col0" class="data row2 col0" >0.500000</td>
#       <td id="T_bc1d1_row2_col1" class="data row2 col1" >0.540816</td>
#       <td id="T_bc1d1_row2_col2" class="data row2 col2" >0.519608</td>
#       <td id="T_bc1d1_row2_col3" class="data row2 col3" >98.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row3" class="row_heading level0 row3" >3.0</th>
#       <td id="T_bc1d1_row3_col0" class="data row3 col0" >0.534483</td>
#       <td id="T_bc1d1_row3_col1" class="data row3 col1" >0.601942</td>
#       <td id="T_bc1d1_row3_col2" class="data row3 col2" >0.566210</td>
#       <td id="T_bc1d1_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row4" class="row_heading level0 row4" >4.0</th>
#       <td id="T_bc1d1_row4_col0" class="data row4 col0" >0.896774</td>
#       <td id="T_bc1d1_row4_col1" class="data row4 col1" >0.917492</td>
#       <td id="T_bc1d1_row4_col2" class="data row4 col2" >0.907015</td>
#       <td id="T_bc1d1_row4_col3" class="data row4 col3" >303.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_bc1d1_row5_col0" class="data row5 col0" >0.719064</td>
#       <td id="T_bc1d1_row5_col1" class="data row5 col1" >0.719064</td>
#       <td id="T_bc1d1_row5_col2" class="data row5 col2" >0.719064</td>
#       <td id="T_bc1d1_row5_col3" class="data row5 col3" >0.719064</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_bc1d1_row6_col0" class="data row6 col0" >0.629585</td>
#       <td id="T_bc1d1_row6_col1" class="data row6 col1" >0.540187</td>
#       <td id="T_bc1d1_row6_col2" class="data row6 col2" >0.550988</td>
#       <td id="T_bc1d1_row6_col3" class="data row6 col3" >598.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bc1d1_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_bc1d1_row7_col0" class="data row7 col0" >0.720108</td>
#       <td id="T_bc1d1_row7_col1" class="data row7 col1" >0.719064</td>
#       <td id="T_bc1d1_row7_col2" class="data row7 col2" >0.711423</td>
#       <td id="T_bc1d1_row7_col3" class="data row7 col3" >598.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Conclusion
# A Support Vector Machine initially predicts students' grades with 75.3% accuracy on the test set without hyperparameter tuning. When dimensionality is reduced to just three key features—
# * Absences,
# * StudyTimeWeekly,
# * and ParentalSupport.
# the accuracy drops to 71.4%.
#
# Including all features improves accuracy, but at a higher resource cost.
#
# A noteworthy takeaway emerges: to excel academically in high school, attending classes and studying the material are crucial. Parental support significantly influences student success, though it's a factor beyond students' control.

# %% [markdown]
# ### Save The Model
# Preparing the trained model for deployment

# %%
X = data.drop(columns=['GradeClass', 'GPA', 'StudentID', 'Age'])
y = data['GradeClass']

# Splitting the data into training and testing sets (e.g., 90% train, 10% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# Create a pipeline
pipeline = Pipeline([
    ('classifier', SVC())
])

# Train the model
pipeline.fit(X_train, y_train)

# Save the model
with open('data_model.pkl', 'wb') as file:
    pickle.dump(pipeline, file)
